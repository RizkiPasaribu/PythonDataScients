# %%
from PIL import Image

# %%
gambar = Image.open("data/train/noninvasive/1.jpg")
gambar
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=208x156 at 0x7F4714FD2A30>

# %%
gambar.show
# Out:
# <bound method Image.show of <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=208x156 at 0x7F4714FD2A30>>

# %%
from torchvision import transforms
from torch import nn

# %%
transform = nn.Sequential(
    transforms.RandomResizedCrop(64),
    transforms.RandomRotation(45)
)

gambar = transform(gambar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8114/3712870466.py in <module>
#       3 )
#       4
# ----> 5 gambar = transform(gambar)
#
# ~/anaconda3/lib/python3.8/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      57
#      58     def __call__(self, img):
# ---> 59         for t in self.transforms:
#      60             img = t(img)
#      61         return img
#
# TypeError: 'RandomResizedCrop' object is not iterable

# %%
gambar
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F466580DBE0>
